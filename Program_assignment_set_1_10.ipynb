# %%
#1. Write a Python program to find sum of elements in list?

L = [ 1,52,58,68,58,54,9,68,6,95,3,6855,32,2]

s = 0

for i in L:
	s= s+i

print("Sum = ",s)

#2. Write a Python program to  Multiply all numbers in the list?

L = [ 1,52,58,68,58,54,9,68,6,95,3,6855,32,2]

s = 1

for i in L:
	s= s*i

print('Product=',s)

#3. Write a Python program to find smallest number in a list?

S= L[0]

for i in L:
	if i<s:
		s = i
print('Smallest number:',s)

#4. Write a Python program to find largest number in a list?

S= L[0]

for i in L:
	if i>s:
		s = i
print("Largest number:",s)


#5. Write a Python program to find second largest number in a list?

s= L[0]

for i in L:
	if i>s:
		l = s
		s = i
print('Largest number:',s)

print('2nd Largest number:',l)

#6. Write a Python program to find N largest elements from a list?

A = L.sort(reverse = True)
print(A)

n= int(input())
ans=[]
ans= L[0:n-1] 

#7. Write a Python program to print even numbers in a list?

for i in L:
	if i%2 == 0:
		print(i,'is even')
	else:
		print(i,'is odd')

#8. Write a Python program to print odd numbers in a List?
#9. Write a Python program to Remove empty List from List?

for i in L:
	if i==[]:
		L.pop(i)

#10. Write a Python program to Cloning or Copying a list?

Lo = L

#11. Write a Python program to Count occurrences of an element in a list?
c = 0
for i in range(0,len(L)-1):
	n = L[i]
	for j in L:
		if n == j:
			c+=1
	print(c,'is number of occurence of',n,'in L')
# Out:
# Sum =  7361
# Product= 294915072448644710400
# Smallest number: 1
# Largest number: 6855
# Largest number: 6855
# 2nd Largest number: 95
# None
# 5
# 6855 is odd
# 95 is odd
# 68 is even
# 68 is even
# 58 is even
# 58 is even
# 54 is even
# 52 is even
# 32 is even
# 9 is odd
# 6 is even
# 3 is odd
# 2 is even
# 1 is odd
# 1 is number of occurence of 6855 in L
# 2 is number of occurence of 95 in L
# 4 is number of occurence of 68 in L
# 6 is number of occurence of 68 in L
# 8 is number of occurence of 58 in L
# 10 is number of occurence of 58 in L
# 11 is number of occurence of 54 in L
# 12 is number of occurence of 52 in L
# 13 is number of occurence of 32 in L
# 14 is number of occurence of 9 in L
# 15 is number of occurence of 6 in L
# 16 is number of occurence of 3 in L
# 17 is number of occurence of 2 in L
